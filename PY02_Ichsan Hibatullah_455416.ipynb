# %% [markdown]
# <p style="text-align: center;">Tugas Metode Komputasi : PY02</p>

# %% [markdown]
# TUGAS I

# %% [markdown]
# Buatlah suatu program sederhana untuk menyelesaikan :
#
# <ol>
# <li>Mencari Kontur Interval (CI) dengan memberikan masukan oleh user berupa penyebut skala </li>
# <li>Mencari mencari nilai ketinggian(h) dan kecepatan(v) setelah bola dilemparkan dengan h0 = 8 m dan v0 = 2 m/s dengan variasi t yakni 0.5 s, lebih dari 0.5 s, dan lebih dari 2s. Besar g =9.8 </li>
# </ol>

# %% [markdown]
# $$h = h_0 + V_0t-\frac12 gt^2$$

# %% [markdown]
# $$v = v_0 - gt$$

# %% [markdown]
# **Script code :**

# %% [markdown]
# No. 1 <br>

# %%
print ("\033[1m" + "\n\nProgram Sederhana Mencari Kontur Interval / Beda Ketinggian (CI)" + "\033[0m") #judul program
print (" ") #spasi

skala = input("Masukkan skala (tidak menggunakan titik) (1:x), x = ") #mendefinisikan variabel skala yang berisi fungsi input untuk memasukkan nilai skala dengan tipe data string

print("Skalanya adalah 1:" + skala) #menuliskan kembali perbandingan skala yang akan dimasukkan dalam perhitungan
print (" ")

kontur = 1 / 2000 * float(skala) #mendefinisikan variabel kontur yang berisi perhitungan kontur interval, variabel skala diubah ke dalam tipe data float

print ("Kontur Interval atau Beda Ketinggian yang di dapat adalah " + str(kontur) + " meter") #menuliskan dalam output hasil dari perhitungan yang telah dilakukan, variabel kontur diubah ke dalam tipe data string
# Out:
# Program Sederhana Mencari Kontur Interval / Beda Ketinggian (CI)
#
# Masukkan skala (tidak menggunakan titik) (1:x), x = 20000
# Skalanya adalah 1:20000
#
# Kontur Interval atau Beda Ketinggian yang di dapat adalah 10.0 meter

# %% [markdown]
# No. 2 <br>

# %%
print("\033[1m" + "Program Sederhana Mencari Nilai Ketinggian (h) dan Kecepatan (v) dengan Variasi Waktu"  + "\033[0m") #judul program
print(" ") #spasi

#Mendefinisikan variabel - variabel yang akan digunakan dalam perhitungan
h0 = 8     #variabel h0 (ketinggian awal)
v0 = 2     #variabel v0 (kecepatan awal)
g  = 9.8   #variabel g  (gravitasi)

#ketika t = 0.5 s (variasi pertama)
t = 0.5    #variabel t  (waktu)
h = (h0+v0*t)-(0.5*g*t**2) #rumus perhitungan ketinggian
v = v0-(g*t) #rumus perhitungan kecepatan
print("Ketinggian benda ketika t=" + str(t) + " adalah " + "%.2f" %h) #menuliskan dalam output hasil dari perhitungan yang telah dilakukan
print(" Kecepatan benda ketika t=" + str(t) + " adalah " + "%.2f" %v)
print (" ")

#ketika t = 1 s (variasi kedua)
t = 1      #variabel t  (waktu)
h = (h0+v0*t)-(0.5*g*t**2) #rumus perhitungan ketinggian
v = v0-(g*t) #rumus perhitungan kecepatan
print("Ketinggian benda ketika t=" + str(t) + " adalah " + "%.2f" %h) #menuliskan dalam output hasil dari perhitungan yang telah dilakukan
print(" Kecepatan benda ketika t=" + str(t) + " adalah " + "%.2f" %v)
print (" ")

#ketika t = 5 s (variasi ketiga)
t = 5      #variabel t  (waktu)
h = (h0+v0*t)-(0.5*g*t**2) #rumus perhitungan ketinggian
v = v0-(g*t) #rumus perhitungan kecepatan
print("Ketinggian benda ketika t=" + str(t) + " adalah " + "%.2f" %h) #menuliskan dalam output hasil dari perhitungan yang telah dilakukan
print(" Kecepatan benda ketika t=" + str(t) + " adalah " + "%.2f" %v)
# Out:
# Program Sederhana Mencari Nilai Ketinggian (h) dan Kecepatan (v) dengan Variasi Waktu
#
# Ketinggian benda ketika t=0.5 adalah 7.78
#  Kecepatan benda ketika t=0.5 adalah -2.90
#
# Ketinggian benda ketika t=1 adalah 5.10
#  Kecepatan benda ketika t=1 adalah -7.80
#
# Ketinggian benda ketika t=5 adalah -104.50
#  Kecepatan benda ketika t=5 adalah -47.00

# %% [markdown]
# **Pembahasan Tugas I:**

# %% [markdown]
#   <div style="text-align: justify"> Pada tugas pertama ini praktikan diminta untuk membuat program sederhana dalam menyelesaikan dua persoalan. Persoalan yang pertama mencari Kontur Interval (CI) dengan memberikan masukan oleh user berupa penyebut skala. Rumus kontur interval atau beda ketinggian merupakan : </div>
#
# $$CI = \frac{1}{2000} \times Skala$$
# &nbsp;
#   <div style="text-align: justify"> Pada program yang pertama, dibuat variabel bernama skala yang berisi fungsi input untuk memasukkan berupa angka ataupun nilai  dalam tipe data string. Lalu didefinisikan variabel baru bernama kontur yang berisi perhitungan dari rumus kontur interval itu sendiri. Tipe data dalam fungsi input ini diubah dari string ke dalam float, karena di dalam python tidak dapat mengkalikan tipe data string dan tipe data float dan ketika mengkalikan antara tipe data string dan tipe data float maka tidak akan ada hasilnya dan akan menghasailkan error, sehingga harus diubah ke dalam tipe data float terlebih dahulu. Lalu setelah didapatkan nilai dari kontur, nilai tersebut di print, ketika di print harus diubah kembali ke dalam string. Untuk menjalankan program ini, user harus memasukkan nilai x berupa angka (jumlahnya bebas) maka program akan berjalan setelah ditekan enter dan akan diperoleh output berupa besarnya skala dan kontur interval. Contohnya yakni ketika user memasukkan angka 20000 sebagai x maka akan diperoleh output berupa skala yang bernilai 1:20000 dan kontur interval sebesar 10 meter.</div>
# &ensp;
#
#   <div style="text-align: justify"> Persoalan yang kedua mencari nilai ketinggian(h) dan kecepatan(v) setelah bola dilemparkan dengan h0 = 8 m dan v0 = 2 m/s dengan variasi t yakni 0.5 s, lebih dari 0.5 s, dan lebih dari 2s. Besar g = 9.8. Dengan rumus ketinggian dan rumus kecepatan yang di dapat : </div>
#
# $$h = h_0 + V_0t-\frac12 gt^2$$
#
# $$v = v_0 - gt$$
# &nbsp;
#   <div style="text-align: justify"> Mula-mula definisikan setiap variabel. Pada program ini ditujukan untuk mencari nilai ketinggian (h) dan kecepatan (v). Variabel t menunjukkan nilai waktu. Disini digunakan nilai t = 0.5, 1, 5 karena menyesuaikan syarat waktu yang ditentukan (t = 0.5, t = lebih dari 0.5, t = lebih dari 2). Variabel h menunjukkan nilai ketinggian yang ingin diperoleh dari rumus yang telah ditentukan. Sedangkan variabel v menunjukkkan nilai v yang ingin dicari dengan rumus yang telah ditentukan. Rumus diulang sebanyak 3 kali untuk memperoleh ketinggian dan kecepatan yang sesuai dengan nilai t yang diinginkan. Print digunakan untuk mencetak nilai h dan v sesuai dengan hasil rumus. Kode "%.2f" %h dan "%.2f" %h digunakan untuk membatasi nilai h dan v maksimal 2 angka dibelakang koma. Output yang diperoleh untuk masing-masing variasi waktu yakni untuk t sebesar 0.5 s, diperoleh nilai ketinggian ( ℎ ) sebesar 7.78 m dan kecepatan ( 𝑣 ) -2.90 m/s. Sedangkan untuk t sebesar 1 s, diperoleh nilai ketinggian ( ℎ ) sebesar 5.10 m dan kecepatan ( 𝑣 ) -7.80 m/s. Dan untuk t sebesar 5 s, diperoleh nilai ketinggian ( ℎ ) sebesar -104.50 m dan kecepatan ( 𝑣 ) -47.00 m/s. Maka dapat ditarik kesimpulan bahwa semakin besar nilai waktu justru akan menghasilkan ketinggian ( ℎ ) dan kecepatan ( 𝑣 ) yang semakin kecil. Dari hal tersebut dapat disimpulkan pula bahwa waktu berbanding terbalik ketinggian ( ℎ ) dan kecepatan ( 𝑣 ), sedangkan ketinggian ( ℎ ) berbanding lurus dengan kecepatan ( 𝑣 ). </div>

# %% [markdown]
# TUGAS II

# %% [markdown]
#  1. Membuat plot sederhana lokasi gempa berdasarkan data Gempa BMKG dari data excel yang telah dibagikan

# %% [markdown]
# **Script code:**

# %%
from pandas import read_excel #untuk membaca data yang terdapat di excel #bisa ditambahin lagi pakai as
import cartopy.crs as ccrs #untuk memproyeksikan koordinat baru dengan (PlateCarree)
import matplotlib.pyplot as plt #keseluruhan script menggunakan modul ini sehingga sangat penting
from matplotlib.image import imread #untuk membaca gambar peta

Data = read_excel('Data Gempa BMKG.xlsx') #Mendefinisikan variabel Data untuk membaca data yang terdapat pada excel

plt.figure(figsize=(10,9)) #Membuat kanvas dari sebuah fungsi, diisikan sebuah fungsi atau parameter figsize dengan ukuran 10 x 9
plt.axes(projection=ccrs.PlateCarree()) #Membuat koordinat baru dengan **proyeksi** ccrs.PlateCarree, mengatur sumbu, menggunakan fungsi axes yang diambil dari matplotlib
plt.imshow(imread('Gambar.TIF'), extent=[-180, 180, -90, 90]) #Gambar hasil citra satelit, gambar TIF, Python tidak bisa membaca gambar dari citra satelit, sehingga menggunakan fungsi imread yang di ambil dari matplotlib.image dan juga menggunakan argumen extent, extent = membatasi dimana letak Indonesia (ngezoom ke wilayah Indonesia aja), karena data - datanya hanya di Indonesia 
plt.xlim([min(Data['Longitude']),max(Data['Longitude'])]) #Fungsi xlim dibangun diatas fungsi lain, xlim membatasi nilai Longitude minimal (terdekat) ke nilai Longitude maksimal (terjauh)
plt.ylim([min(Data['Latitude']),max(Data['Latitude'])]) #Fungsi ylim dibangun diatas fungsi lain, ylim membatasi nilai Latitude minimal (terdekat) ke nilai Latitude maksimal (terjauh)
plt.scatter(Data['Longitude'],Data['Latitude'],c='black') #Memasukkan dan menitikkan lokasi - lokasi gempa di wilayah Indonesia dari data - data gempa (longitude dan latitude) yang telah disediakan, titiknya disini diberi warna hitam
plt.title('PERSEBARAN GEMPA 2020') #Menuliskan Judul
plt.show() #Menampilkan Gambar

# %% [markdown]
# **Pembahasan Tugas II :**

# %% [markdown]
#    <div style="text-align: justify"> Pada tugas praktikum kali ini, praktikan diminta membuat program sederhana untuk memplot titik gempa di peta Indonesia berdasarkan data BMKG yang diberikan. Dimulai dengan meng-import modul-modul yang dibutuhkan dalam script plotting gempa. Dikarenakan python tidak bisa membaca data excel, maka dibutuhkan fungsi untuk membaca data excel. Modul pandas diimport berguna untuk membaca data excel, dengan funsi read_excel. modul cartopy digunakan sebagai proyeksi untuk menentukan koordinat baru. proyeksi cartopy yang digunakan berupa PlateCarree agar bisa memproyeksikan peta dalam bidang datar. modul matplotlib digunakan untuk menghasilkan plot dengan kualitas tinggi. matplotlib dapat digunakan diberbagai platform. matplotlib.pyplot adalah paket python yang digunakan untuk grafik 2D. didalamnya terdapat banyak jenis plot, disini matplotlib.pyplot memanggil scatter plot untuk memplot persebaran gempa bumi di Indonesia. matplotlib berperan penting dalam pembuatan plot persebaran gempa bumi di Indonesia, karena pembuatan plot persebaran gempa bumi di Indonesia menggunakan modul matplotlib. </div>
#    &nbsp;
#    <div style="text-align: justify"> Setelah mengimpor semua modul, langkah selanjutnya adalah membuat variabel data yang berfungsi untuk membaca excel. Dimana di dalam excel berisikan data longitude dan latitude peta Indonesia, fungsinya berupa read_excel yang telah diimport dari modul pandas. Kemudian membuat kanvas dari sebuah  fungsi dengan parameter figsize dengan ukuran 10 x 9. Setelah itu membuat koordinat baru dengan proyeksi ccrs. PlateCarree merupakan salah satu proyeksi dari modul cartopy yang berfungsi untuk mengatur sumbu dengan menggunakan fungsi axes yang diambil dari matplotlib. Kemudian peta dengan format .TIF dapat dibaca menggunakan parameter imread yang telah di import sebelumnya, karena python sendiri tidak bisa membaca gambar citra satelit yang telah diberikan. Argumen extent ditambah yang berfungsi untuk membatasi letak atau wilayah Indonesia saja, karena peta yang diberikan merupakan peta dunia. Dilanjut dengan membatasi nilai longitude minimal ke nilai longitude maksimal dengan menggunakan fungsi xlim, begitu pula berlaku pada latitude dengan menggunakan fungsi ylim. Kemudian fungsi scatter digunakan untuk memasukkan dan memplot lokasi gempa di wilayah Indonesia dari data gempa (longitude dan latitude) yang telah tersedia. Langkah terakhir menambahkan judul dengan fungsi title dan menampilkan gambar dengan fungsi show dari modul matplotlib.pyplot. Hasil dari program menghasilkan output berupa plot sederhana persebaran gempa di Indonesia tahun 2020 sesuai data BMKG yang diberikan yang ditunjukkan dengan titik hitam untuk setiap lokasi gempa yang ada di Indonesia. </div>
